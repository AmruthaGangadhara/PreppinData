# %%
import pandas as pd
from datetime import date as dt

# %%
df=pd.read_csv(r'C:\Users\amrut\OneDrive\Documents\Preppin Data\Week_1\PD_2023_Wk_1_Input.csv')

# %%
df.head()
# Out:
#   Transaction_Code  Value  Customer_Code  Online_or_In_Person  \
# 0  DTB-716-679-576   1448         100001                    2
# 1   DS-795-814-303   7839         100001                    2
# 2  DSB-807-592-406   5520         100005                    1
# 3   DS-367-545-264   7957         100007                    2
# 4  DSB-474-374-857   5375         100000                    2
#
#       Transaction_Date
# 0  20/03/2023 00:00:00
# 1  15/11/2023 00:00:00
# 2  14/07/2023 00:00:00
# 3  18/08/2023 00:00:00
# 4  26/08/2023 00:00:00

# %% [markdown]
# #### Split the Transaction Code to extract the letters at the start of the transaction code. These identify the bank who processes the transaction

# %%
#Used lambda expression to split each string by '-' and slicing the first part in the result.
df['Bank']=df['Transaction_Code'].apply(lambda x: x.split('-')[0])
df
# Out:
#     Transaction_Code  Value  Customer_Code Online_or_In_Person  \
# 0    DTB-716-679-576   1448         100001           In Person
# 1     DS-795-814-303   7839         100001           In Person
# 2    DSB-807-592-406   5520         100005              Online
# 3     DS-367-545-264   7957         100007           In Person
# 4    DSB-474-374-857   5375         100000           In Person
# ..               ...    ...            ...                 ...
# 360  DTB-116-439-102   6708         100001              Online
# 361   DS-849-981-514   8500         100000           In Person
# 362   DS-726-686-279   9455         100006           In Person
# 363   DS-551-937-380    475         100002              Online
# 364   DS-976-542-770   7364         100009              Online
#
#     Transaction_Date Bank   day_name  new
# 0             Monday  DTB     Monday  DTB
# 1          Wednesday   DS  Wednesday   DS
# 2             Friday  DSB     Friday  DSB
# ...

# %% [markdown]
# #### Rename the values in the Online or In-person field, Online of the 1 values and In-Person for the 2 values.

# %%
#using the replace function within pandas
df['Online_or_In_Person']=df['Online_or_In_Person'].replace([1,2],['Online','In Person'])
df
# Out:
#     Transaction_Code  Value  Customer_Code Online_or_In_Person  \
# 0    DTB-716-679-576   1448         100001           In Person
# 1     DS-795-814-303   7839         100001           In Person
# 2    DSB-807-592-406   5520         100005              Online
# 3     DS-367-545-264   7957         100007           In Person
# 4    DSB-474-374-857   5375         100000           In Person
# ..               ...    ...            ...                 ...
# 360  DTB-116-439-102   6708         100001              Online
# 361   DS-849-981-514   8500         100000           In Person
# 362   DS-726-686-279   9455         100006           In Person
# 363   DS-551-937-380    475         100002              Online
# 364   DS-976-542-770   7364         100009              Online
#
#         Transaction_Date Bank
# 0    20/03/2023 00:00:00  DTB
# 1    15/11/2023 00:00:00   DS
# 2    14/07/2023 00:00:00  DSB
# 3    18/08/2023 00:00:00   DS
# 4    26/08/2023 00:00:00  DSB
# ...

# %% [markdown]
# #### Change the date to be the day of the week

# %%
#converting the date to day name using strftime function
df['day_name'] = pd.to_datetime(df['Transaction_Date']).dt.strftime('%A')

# %%
df
# Out:
#     Transaction_Code  Value  Customer_Code Online_or_In_Person  \
# 0    DTB-716-679-576   1448         100001           In Person
# 1     DS-795-814-303   7839         100001           In Person
# 2    DSB-807-592-406   5520         100005              Online
# 3     DS-367-545-264   7957         100007           In Person
# 4    DSB-474-374-857   5375         100000           In Person
# ..               ...    ...            ...                 ...
# 360  DTB-116-439-102   6708         100001              Online
# 361   DS-849-981-514   8500         100000           In Person
# 362   DS-726-686-279   9455         100006           In Person
# 363   DS-551-937-380    475         100002              Online
# 364   DS-976-542-770   7364         100009              Online
#
#         Transaction_Date Bank   day_name
# 0    20/03/2023 00:00:00  DTB     Monday
# 1    15/11/2023 00:00:00   DS  Wednesday
# 2    14/07/2023 00:00:00  DSB     Friday
# 3    18/08/2023 00:00:00   DS     Friday
# ...

# %% [markdown]
# #### Different levels of detail are required in the outputs. You will need to sum up the values of the transactions in three ways (help):
# 1. Total Values of Transactions by each bank
# 2. Total Values by Bank, Day of the Week and Type of Transaction (Online or In-Person)
# 3. Total Values by Bank and Customer Code

# %% [markdown]
# #### 1.Total Values of Transactions by each bank

# %%
values_by_bank= df.groupby('Bank')['Value'].sum().reset_index(name='Values')

values_by_bank.head()
# Out:
#   Bank  Values
# 0   DS  653940
# 1  DSB  530489
# 2  DTB  618238

# %% [markdown]
# #### 2.Total Values by Bank, Day of the Week and Type of Transaction (Online or In-Person)

# %%
values= df.groupby(['Bank','Online_or_In_Person','day_name'])['Value'].sum().reset_index(name='Values')
values
# Out:
#    Bank Online_or_In_Person   day_name  Values
# 0    DS           In Person     Friday   50925
# 1    DS           In Person     Monday   50810
# 2    DS           In Person   Saturday   41141
# 3    DS           In Person     Sunday   70291
# 4    DS           In Person   Thursday   39805
# 5    DS           In Person    Tuesday   42519
# 6    DS           In Person  Wednesday   63957
# 7    DS              Online     Friday   61713
# 8    DS              Online     Monday   34668
# 9    DS              Online   Saturday   64362
# 10   DS              Online     Sunday   40022
# 11   DS              Online   Thursday   11448
# 12   DS              Online    Tuesday   41709
# 13   DS              Online  Wednesday   40570
# 14  DSB           In Person     Friday   31640
# 15  DSB           In Person     Monday   39507
# 16  DSB           In Person   Saturday   72116
# 17  DSB           In Person     Sunday   38907
# 18  DSB           In Person   Thursday   36124
# ...

# %% [markdown]
# #### 3.Total Values by Bank and Customer Code

# %%
bank_cust=df.groupby(['Bank','Customer_Code'])['Value'].sum().reset_index(name='Total_values')
bank_cust
# Out:
#    Bank  Customer_Code  Total_values
# 0    DS         100000         57909
# 1    DS         100001         53063
# 2    DS         100002         69803
# 3    DS         100003         25482
# 4    DS         100004         63315
# 5    DS         100005         39668
# 6    DS         100006         77636
# 7    DS         100007         76190
# 8    DS         100008         56400
# 9    DS         100009         56581
# 10   DS         100010         77893
# 11  DSB         100000         27585
# 12  DSB         100001         67856
# 13  DSB         100002         27936
# 14  DSB         100003         58154
# 15  DSB         100004         39003
# 16  DSB         100005         56396
# 17  DSB         100006         32333
# 18  DSB         100007         29702
# 19  DSB         100008         47121
# 20  DSB         100009         51749
# 21  DSB         100010         92654
# 22  DTB         100000         77252
# 23  DTB         100001         60675
# ...

# %%
print(values.shape)
print(values_by_bank.shape)
print(bank_cust.shape)
# Out:
# (42, 4)
# (3, 2)
# (33, 3)

# %%
values.to_csv(r'C:\Users\amrut\OneDrive\Documents\Preppin Data\Week_1\values.csv',index=False)

# %%
values_by_bank.to_csv(r'C:\Users\amrut\OneDrive\Documents\Preppin Data\Week_1\values_by_bank.csv',index=False)

# %%
bank_cust.to_csv(r'C:\Users\amrut\OneDrive\Documents\Preppin Data\Week_1\bank_cust.csv',index=False)

# %%
test_df=df
test_df
# Out:
#     Transaction_Code  Value  Customer_Code Online_or_In_Person  \
# 0    DTB-716-679-576   1448         100001           In Person
# 1     DS-795-814-303   7839         100001           In Person
# 2    DSB-807-592-406   5520         100005              Online
# 3     DS-367-545-264   7957         100007           In Person
# 4    DSB-474-374-857   5375         100000           In Person
# ..               ...    ...            ...                 ...
# 360  DTB-116-439-102   6708         100001              Online
# 361   DS-849-981-514   8500         100000           In Person
# 362   DS-726-686-279   9455         100006           In Person
# 363   DS-551-937-380    475         100002              Online
# 364   DS-976-542-770   7364         100009              Online
#
#     Transaction_Date Bank   day_name
# 0             Monday  DTB     Monday
# 1          Wednesday   DS  Wednesday
# 2             Friday  DSB     Friday
# 3             Friday   DS     Friday
# ...

# %%
test_df['new']=test_df['Transaction_Code'].apply(lambda x: x.split('-')[0])
test_df
# Out:
#     Transaction_Code  Value  Customer_Code Online_or_In_Person  \
# 0    DTB-716-679-576   1448         100001           In Person
# 1     DS-795-814-303   7839         100001           In Person
# 2    DSB-807-592-406   5520         100005              Online
# 3     DS-367-545-264   7957         100007           In Person
# 4    DSB-474-374-857   5375         100000           In Person
# ..               ...    ...            ...                 ...
# 360  DTB-116-439-102   6708         100001              Online
# 361   DS-849-981-514   8500         100000           In Person
# 362   DS-726-686-279   9455         100006           In Person
# 363   DS-551-937-380    475         100002              Online
# 364   DS-976-542-770   7364         100009              Online
#
#     Transaction_Date Bank   day_name  new
# 0             Monday  DTB     Monday  DTB
# 1          Wednesday   DS  Wednesday   DS
# 2             Friday  DSB     Friday  DSB
# ...
